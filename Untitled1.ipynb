# %%
# %run verify_setup.py
# Out:
# ╔==========================================================╗
# ║               PDR SETUP VERIFICATION                    ║
# ╚==========================================================╝
#
# ...
# Checking imports...
# ...
# ✓ PyTorch installed
# ✓ OpenAI Gym installed
# ✓ NumPy installed
#
# ...
# Checking custom files...
# ...
# ✓ Priority Dispatching Rules     (PDRs.py)
# ✓ Feature Extractor              (state_features.py)
# ✓ PDR Environment                (JSSP_Env_PDR.py)
# ✓ Training Script                (PPO_jssp_PDR.py)
# ✓ Testing Script                 (test_learned_PDR.py)
# ✓ Instance Generator             (uniform_instance_gen.py)
# ✓ Permissible Left Shift         (permissibleLS.py)
# ✓ Lower Bound Update             (updateEntTimeLB.py)
# ✓ Adjacency Matrix Update        (updateAdjMat.py)
# ✓ Actor-Critic PDR Model         (models/actor_critic_pdr.py)
#
# ...
# Testing PDR implementations...
# ...
# Testing 10 PDRs on dummy problem...
#   ✓ SPT        → operation 1
#   ✓ LPT        → operation 6
# ...

# %%
# %run PPO_jssp_PDR.py
# Out:
# Training PPO with PDR selection
# Problem size: 6x6
# Feature dimension: 84
# Number of PDRs: 10
# Number of environments: 4
# Device: cpu
# ------------------------------------------------------------
# Episode     1 | Reward:  -696.50 | V-loss: 0.741205 | Time:   0.42s
# Episode     2 | Reward:  -675.75 | V-loss: 0.594007 | Time:   0.24s
# Episode     3 | Reward:  -594.25 | V-loss: 0.493835 | Time:   0.23s
# Episode     4 | Reward:  -602.50 | V-loss: 0.363093 | Time:   0.23s
# Episode     5 | Reward:  -655.50 | V-loss: 0.317466 | Time:   0.24s
# Episode     6 | Reward:  -605.25 | V-loss: 0.161519 | Time:   0.23s
# Episode     7 | Reward:  -644.00 | V-loss: 0.246759 | Time:   0.23s
# Episode     8 | Reward:  -609.75 | V-loss: 0.217288 | Time:   0.23s
# Episode     9 | Reward:  -624.25 | V-loss: 0.128464 | Time:   0.23s
# Episode    10 | Reward:  -648.75 | V-loss: 0.057964 | Time:   0.24s
# Episode    11 | Reward:  -575.25 | V-loss: 0.288746 | Time:   0.24s
# ...
